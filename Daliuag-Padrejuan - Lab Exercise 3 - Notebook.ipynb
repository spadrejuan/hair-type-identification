# %% [markdown]
# # The Source Code for Lab Exercise 3.
# ## Steps
# 1. Preprocess the Data.
# 2. Create a Train and Test Split
# 3. Create a Convolutional Neural Network using Keras.
# 4. Experiment on Various Elements
# 5. Discussion and Analysis of Experiments.

# %% [markdown]
# # Possible Things to Experiment on
# 1. Other Preprocessing methods for Images.
# 2. Adding Max Pooling.
# 3. Changing number of Filters.
# 4. Changing Kernel Size.
# 5. Changing Learning Rate.
# 6. Changing Optimizers.

# %% [markdown]
# ### Check Keras and Tensforflow Version and check for GPU compatibilities

# %%
import sys
import tensorflow as tf
import keras
import platform

print(f"Python Platform: {platform.version()}")
print(f"Python Version: {sys.version}")
print(f"Tensorflow version: {tf.__version__}")
print(f"Keras version: {keras.__version__}")
print()
gpu = len(tf.config.list_physical_devices('GPU')) > 0
print(f"GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# Python Platform: Darwin Kernel Version 23.4.0: Fri Mar 15 00:19:22 PDT 2024; root:xnu-10063.101.17~1/RELEASE_ARM64_T8112
# Python Version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:51:49) [Clang 16.0.6 ]
# Tensorflow version: 2.16.1
# Keras version: 3.2.1
#
# GPU is available

# %% [markdown]
# ### Checking for Invalid datasets

# %%
from pathlib import Path
import imghdr
import os

DATA_DIR = "hair_types"
IMAGE_EXTENSIONS = [".png", ".jpg"]  # add there all your images file extensions

img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]
for filepath in Path(DATA_DIR).rglob("*"):
    if filepath.suffix.lower() in IMAGE_EXTENSIONS:
        img_type = imghdr.what(filepath)
        if img_type is None:
            print(f"{filepath} is not an image")
            os.remove(filepath)
        elif img_type not in img_type_accepted_by_tf:
            print(f"{filepath} is a {img_type}, not accepted by TensorFlow")
            os.remove(filepath)

# %% [markdown]
# ## Preprocessing Images Section

# %% [markdown]
# ### Import Tensorflow and Keras

# %%
import tensorflow as tf
import keras # we define like this for IntelliSense

# We define the constants for our images
BATCH_SIZE = 16
HEIGHT = 128
WIDTH = 128
IMAGE_SIZE = (HEIGHT, WIDTH)

# %% [markdown]
# ### Loading Datasets for the Validation and Training splits

# %%
train_dataset = keras.preprocessing.image_dataset_from_directory(
    directory="hair_types",
    batch_size=BATCH_SIZE,
    image_size=IMAGE_SIZE,
    seed=1337, # same as Demo
    validation_split=0.2, # use 20% as validation
    subset="training",
    label_mode="categorical"
)
val_dataset = keras.preprocessing.image_dataset_from_directory(
    directory="hair_types",
    batch_size=BATCH_SIZE,
    image_size=IMAGE_SIZE,
    seed=1337, # same as Demo
    validation_split=0.2, # use 20% as validation
    subset="validation",
    label_mode="categorical"
)
# The target labels
class_names = train_dataset.class_names
print(class_names)
# Out:
# Found 981 files belonging to 3 classes.
# Using 785 files for training.
# Found 981 files belonging to 3 classes.
# Using 196 files for validation.
# ['Curly_Hair', 'Straight_Hair', 'Wavy_Hair']

# %% [markdown]
# ### Visualizing the initial dataset

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[np.argmax(labels[i])])
    plt.axis("off")
# Out:
# 2024-04-28 17:10:05.539148: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ### Ways to Preprocess Images - Data Augmentation using keras.Layers

# %%
from keras import layers # We import like this for IntelliSense
data_augmentation_methods = keras.Sequential([
   layers.RandomFlip('horizontal_and_vertical'),
   layers.RandomRotation(factor=0.8),
   layers.RandomBrightness(factor=0.2),
   layers.RandomTranslation(height_factor=0.2, width_factor=0.2),  
   # Shift within 20% of image size
   layers.RandomZoom(height_factor=0.2, width_factor=0.2),
   layers.RandomContrast(factor=0.4),
])

# %% [markdown]
# ### Visualizing how these methods affect images

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
    for i in range(9):
        augmented_images = data_augmentation_methods(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(np.array(augmented_images[0]).astype("uint8"))
        plt.axis("off")
plt.show()
# Out:
# 2024-04-28 17:10:06.603716: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ### GPU Optimization

# %%
from tensorflow import data as tf_data
# Configuring dataset for performance
# Prefetching samples in GPU memory helps maximize GPU utilization.
train_dataset = train_dataset.prefetch(tf_data.AUTOTUNE)
val_dataset = val_dataset.prefetch(tf_data.AUTOTUNE)

# %% [markdown]
# ## Creating a Convolutional Neural Network using Keras

# %%
# 2. Adding Max Pooling.
# 3. Changing number of Filters.
# 4. Changing Kernel Size.
model = keras.models.Sequential()

# # Preprocessing Layer
model.add(keras.Input(shape=IMAGE_SIZE + (3,)))
model.add(layers.Rescaling(1.0 / 255))

# Convolutional Layer
model.add(layers.Conv2D(filters=32, kernel_size=(3, 3), strides=(1,1), activation='relu'))

model.add(layers.Conv2D(filters=64, kernel_size=(3, 3), strides=(1,1), activation='relu'))
model.add(layers.Dropout(0.7))
model.add(layers.MaxPooling2D(pool_size=(2,2)))

model.add(layers.Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), activation="relu"))
model.add(layers.Dropout(0.7))
model.add(layers.MaxPooling2D(pool_size=(2,2)))

# Output Layer
model.add(layers.Flatten())

model.add(layers.Dense(units=256, activation="relu"))
model.add(layers.Dropout(0.7))

model.add(layers.Dense(units=3, activation="softmax"))


# Compile the model
model.compile(
    optimizer=keras.optimizers.Adam(0.001),
    loss=keras.losses.CategoricalCrossentropy(),
    metrics=['accuracy'],
)

model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_1 (Rescaling)         │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 124, 124, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 124, 124, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 60, 60, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 60, 60, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 30, 30, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 115200)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │    29,491,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,585,475 (112.86 MB)
#  Trainable params: 29,585,475 (112.86 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training the Model

# %% [markdown]
# ### Util Methods

# %%
# Dynamic Learning Rate
def lr_schedule(epoch):
    initial_lr = 0.001
    drop = 0.1
    epochs_drop = 8
    lr = initial_lr * np.power(drop, np.floor((1 + epoch) 
                                              / epochs_drop))
    return lr

# %%
# 5. Changing Learning Rate.
# 6. Changing Optimizers.
EPOCHS = 50
stop = keras.callbacks.EarlyStopping(patience=8, monitor="val_loss", start_from_epoch=15, verbose=1)
lr_scheduler = keras.callbacks.LearningRateScheduler(lr_schedule)
callbacks = [
    stop,
    keras.callbacks.LearningRateScheduler(lr_schedule),
]

cnn = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=EPOCHS,  
    callbacks=callbacks,
)
# Out:
# Epoch 1/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step - accuracy: 0.3552 - loss: 5.7619 - val_accuracy: 0.2857 - val_loss: 1.0991 - learning_rate: 0.0010
# Epoch 2/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 121ms/step - accuracy: 0.4013 - loss: 1.0927 - val_accuracy: 0.3724 - val_loss: 1.0928 - learning_rate: 0.0010
# Epoch 3/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 121ms/step - accuracy: 0.4584 - loss: 1.0415 - val_accuracy: 0.4745 - val_loss: 1.0759 - learning_rate: 0.0010
# Epoch 4/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.5798 - loss: 0.9267 - val_accuracy: 0.5000 - val_loss: 1.0416 - learning_rate: 0.0010
# Epoch 5/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 120ms/step - accuracy: 0.6449 - loss: 0.8268 - val_accuracy: 0.4796 - val_loss: 1.0190 - learning_rate: 0.0010
# Epoch 6/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.6586 - loss: 0.7738 - val_accuracy: 0.4745 - val_loss: 1.0151 - learning_rate: 0.0010
# Epoch 7/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 121ms/step - accuracy: 0.7565 - loss: 0.6354 - val_accuracy: 0.5357 - val_loss: 0.9772 - learning_rate: 0.0010
# Epoch 8/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 120ms/step - accuracy: 0.7845 - loss: 0.5291 - val_accuracy: 0.5561 - val_loss: 0.9636 - learning_rate: 1.0000e-04
# Epoch 9/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.8470 - loss: 0.4160 - val_accuracy: 0.5612 - val_loss: 0.9635 - learning_rate: 1.0000e-04
# Epoch 10/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.8625 - loss: 0.4073 - val_accuracy: 0.5612 - val_loss: 0.9566 - learning_rate: 1.0000e-04
# Epoch 11/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.8423 - loss: 0.3561 - val_accuracy: 0.5612 - val_loss: 0.9548 - learning_rate: 1.0000e-04
# Epoch 12/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.8521 - loss: 0.3554 - val_accuracy: 0.5612 - val_loss: 0.9568 - learning_rate: 1.0000e-04
# Epoch 13/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 121ms/step - accuracy: 0.8801 - loss: 0.2791 - val_accuracy: 0.5663 - val_loss: 0.9512 - learning_rate: 1.0000e-04
# Epoch 14/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.9111 - loss: 0.2736 - val_accuracy: 0.5714 - val_loss: 0.9500 - learning_rate: 1.0000e-04
# Epoch 15/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.8889 - loss: 0.3225 - val_accuracy: 0.5663 - val_loss: 0.9470 - learning_rate: 1.0000e-04
# Epoch 16/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.9046 - loss: 0.2413 - val_accuracy: 0.5612 - val_loss: 0.9492 - learning_rate: 1.0000e-05
# Epoch 17/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9130 - loss: 0.2602 - val_accuracy: 0.5663 - val_loss: 0.9491 - learning_rate: 1.0000e-05
# Epoch 18/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 121ms/step - accuracy: 0.9135 - loss: 0.2600 - val_accuracy: 0.5612 - val_loss: 0.9496 - learning_rate: 1.0000e-05
# Epoch 19/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.8937 - loss: 0.2781 - val_accuracy: 0.5612 - val_loss: 0.9490 - learning_rate: 1.0000e-05
# Epoch 20/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.9291 - loss: 0.2069 - val_accuracy: 0.5612 - val_loss: 0.9494 - learning_rate: 1.0000e-05
# Epoch 21/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.9379 - loss: 0.1931 - val_accuracy: 0.5612 - val_loss: 0.9505 - learning_rate: 1.0000e-05
# Epoch 22/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - accuracy: 0.9254 - loss: 0.2111 - val_accuracy: 0.5612 - val_loss: 0.9504 - learning_rate: 1.0000e-05
# Epoch 23/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.9182 - loss: 0.2222 - val_accuracy: 0.5663 - val_loss: 0.9519 - learning_rate: 1.0000e-05
# Epoch 24/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.9054 - loss: 0.2591 - val_accuracy: 0.5663 - val_loss: 0.9521 - learning_rate: 1.0000e-06
# Epoch 25/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.9144 - loss: 0.2193 - val_accuracy: 0.5663 - val_loss: 0.9521 - learning_rate: 1.0000e-06
# Epoch 26/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.8958 - loss: 0.2191 - val_accuracy: 0.5663 - val_loss: 0.9521 - learning_rate: 1.0000e-06
# Epoch 27/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9153 - loss: 0.2360 - val_accuracy: 0.5663 - val_loss: 0.9520 - learning_rate: 1.0000e-06
# Epoch 27: early stopping

# %% [markdown]
# ## Evaluation of the Model

# %% [markdown]
# ### Predicting a specific Image

# %%
img_path = (
    "hair_types/Curly_Hair/02dac897d1dec9ba8c057a11d041ada8--" +
    "layered-natural-hair-natural-black-hairstyles.jpg"
)

img = tf.keras.preprocessing.image.load_img(img_path, 
                                            target_size=(HEIGHT, WIDTH))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

# Predict probabilities
predictions = model.predict(img_array)[0]  

# Scale predictions to percentages
total_percentage = sum(predictions)
scaled_predictions = [p * 100 / total_percentage for p in predictions]

class_names = ["Curly Hair", "Straight Hair", "Wavy Hair"]  
percentage_str = ", ".join(["%.2f percent %s" % (p, class_names[i]) for i, 
                            p in enumerate(scaled_predictions)])
print("This image is " + percentage_str + ".")
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# This image is 50.62 percent Curly Hair, 29.77 percent Straight Hair, 19.61 percent Wavy Hair.

# %% [markdown]
# ### Predicting a Random Image

# %%
import os
import random
folder_number = random.randint(1, 3)  # Generate a random number between 1-3
if folder_number == 1:
    dataset_dir = "hair_types/Curly_Hair/"
elif folder_number == 2:
    dataset_dir = "hair_types/Straight_Hair/"
else:
    dataset_dir = "hair_types/Wavy_Hair/"

print(dataset_dir)
file_list = os.listdir(dataset_dir)

random_file = random.choice(file_list)
print(random_file)
image_path = os.path.join(dataset_dir, random_file)

img = tf.keras.preprocessing.image.load_img(image_path, 
                                            target_size=(HEIGHT, WIDTH))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

# Make predictions
predictions = model.predict(img_array)[0]


# Scale predictions to percentages
total_percentage = sum(predictions)
scaled_predictions = [p * 100 / total_percentage for p in predictions]

class_names = ["Curly Hair", "Straight Hair", "Wavy Hair"]  
percentage_str = ", ".join(["%.2f percent %s" % (p, class_names[i]) for i, 
                            p in enumerate(scaled_predictions)])
print("This image is " + percentage_str + ".")
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# hair_types/Straight_Hair/
# 5fad8c7a7825bf522ecd213a771d5e80.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# This image is 21.59 percent Curly Hair, 47.13 percent Straight Hair, 31.28 percent Wavy Hair.

# %% [markdown]
# ### Visualization in Respect to Epochs

# %%
acc = cnn.history['accuracy']
val_acc = cnn.history['val_accuracy']

loss = cnn.history['loss']
val_loss = cnn.history['val_loss']
if stop.stopped_epoch != 0:
    epochs_range = range(stop.stopped_epoch+1)
else:
    epochs_range = range(EPOCHS)
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
