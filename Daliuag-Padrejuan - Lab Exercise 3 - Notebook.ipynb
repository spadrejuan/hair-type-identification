# %% [markdown]
# # The Source Code for Lab Exercise 3.
# ## Steps
# 1. Preprocess the Data.
# 2. Create a Train and Test Split
# 3. Create a Convolutional Neural Network using Keras.
# 4. Experiment on Various Elements
# 5. Discussion and Analysis of Experiments.

# %% [markdown]
# # Possible Things to Experiment on
# 1. Other Preprocessing methods for Images.
# 2. Adding Max Pooling.
# 3. Changing number of Filters.
# 4. Changing Kernel Size.
# 5. Changing Learning Rate.
# 6. Changing Optimizers.

# %% [markdown]
# ### Check Keras and Tensforflow Version and check for GPU compatibilities

# %%
import sys
import tensorflow as tf
import keras
import platform

print(f"Python Platform: {platform.version()}")
print(f"Python Version: {sys.version}")
print(f"Tensorflow version: {tf.__version__}")
print(f"Keras version: {keras.__version__}")
print()
gpu = len(tf.config.list_physical_devices('GPU')) > 0
print(f"GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# Python Platform: Darwin Kernel Version 23.4.0: Fri Mar 15 00:19:22 PDT 2024; root:xnu-10063.101.17~1/RELEASE_ARM64_T8112
# Python Version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:51:49) [Clang 16.0.6 ]
# Tensorflow version: 2.16.1
# Keras version: 3.2.1
#
# GPU is available

# %% [markdown]
# ### Checking for Invalid datasets

# %%
from pathlib import Path
import imghdr
import os

DATA_DIR = "hair_types"
IMAGE_EXTENSIONS = [".png", ".jpg"]  # add there all your images file extensions

img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]
for filepath in Path(DATA_DIR).rglob("*"):
    if filepath.suffix.lower() in IMAGE_EXTENSIONS:
        img_type = imghdr.what(filepath)
        if img_type is None:
            print(f"{filepath} is not an image")
            os.remove(filepath)
        elif img_type not in img_type_accepted_by_tf:
            print(f"{filepath} is a {img_type}, not accepted by TensorFlow")
            os.remove(filepath)

# %% [markdown]
# ## Preprocessing Images Section

# %% [markdown]
# ### Import Tensorflow and Keras

# %%
import tensorflow as tf
import keras # we define like this for IntelliSense

# We define the constants for our images
BATCH_SIZE = 16
HEIGHT = 256
WIDTH = 256
IMAGE_SIZE = (HEIGHT, WIDTH)

# %% [markdown]
# ### Loading Datasets for the Validation and Training splits

# %%
train_dataset = keras.preprocessing.image_dataset_from_directory(
    directory="hair_types",
    batch_size=BATCH_SIZE,
    image_size=IMAGE_SIZE,
    seed=1337, # same as Demo
    validation_split=0.2, # use 20% as validation
    subset="training",
    label_mode="categorical"
)
val_dataset = keras.preprocessing.image_dataset_from_directory(
    directory="hair_types",
    batch_size=BATCH_SIZE,
    image_size=IMAGE_SIZE,
    seed=1337, # same as Demo
    validation_split=0.2, # use 20% as validation
    subset="validation",
    label_mode="categorical"
)
# The target labels
class_names = train_dataset.class_names
print(class_names)
# Out:
# Found 981 files belonging to 3 classes.
# Using 785 files for training.
# Found 981 files belonging to 3 classes.
# Using 196 files for validation.
# ['Curly_Hair', 'Straight_Hair', 'Wavy_Hair']

# %% [markdown]
# ### Visualizing the initial dataset

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[np.argmax(labels[i])])
    plt.axis("off")
# Out:
# 2024-04-26 14:53:39.070126: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ### Ways to Preprocess Images - Data Augmentation using keras.Layers

# %%
from keras import layers # We import like this for IntelliSense
data_augmentation_methods = keras.Sequential([
   layers.RandomFlip('horizontal_and_vertical'),
   layers.RandomRotation(factor=0.8),
   layers.RandomBrightness(factor=0.2),
   #layers.RandomTranslation(height_factor=0.2, width_factor=0.2),  
   # Shift within 20% of image size
   #layers.RandomZoom(height_factor=0.2, width_factor=0.2),
   layers.RandomContrast(factor=0.4),
])

# %% [markdown]
# ### Visualizing how these methods affect images

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
    for i in range(9):
        augmented_images = data_augmentation_methods(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(np.array(augmented_images[0]).astype("uint8"))
        plt.axis("off")
plt.show()
# Out:
# 2024-04-26 14:53:40.276167: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ### GPU Optimization

# %%
from tensorflow import data as tf_data
# Configuring dataset for performance
# Prefetching samples in GPU memory helps maximize GPU utilization.
train_dataset = train_dataset.prefetch(tf_data.AUTOTUNE)
val_dataset = val_dataset.prefetch(tf_data.AUTOTUNE)

# %% [markdown]
# ## Creating a Convolutional Neural Network using Keras

# %%
# 2. Adding Max Pooling.
# 3. Changing number of Filters.
# 4. Changing Kernel Size.
from keras import regularizers
model = keras.models.Sequential()

# Preprocessing Layer
model.add(keras.Input(shape=IMAGE_SIZE + (3,)))
model.add(layers.Rescaling(1.0 / 255))

# Convolutional Layer
model.add(layers.Conv2D(filters=16, kernel_size=(3, 3), activation='relu'))
model.add(layers.BatchNormalization(synchronized=True))
model.add(layers.MaxPooling2D(pool_size=(2,2)))

model.add(layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
model.add(layers.MaxPooling2D(pool_size=(2,2)))

model.add(layers.Conv2D(filters=64, kernel_size=(3,3), activation="relu"))
model.add(layers.MaxPooling2D(pool_size=(2,2)))

model.add(layers.Conv2D(filters=128, kernel_size=(3,3), activation="relu"))
model.add(layers.MaxPooling2D(pool_size=(2,2)))

# Output Layer
model.add(layers.GlobalMaxPooling2D())
model.add(layers.Flatten())

model.add(layers.Dense(units=256, activation="relu"))
model.add(layers.Dropout(0.5))


model.add(layers.Dense(units=3, activation="softmax"))


# Compile the model
model.compile(
    optimizer=keras.optimizers.Adam(0.001),
    loss=keras.losses.CategoricalCrossentropy(),
    metrics=['accuracy'],
)

model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_2 (Rescaling)         │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 254, 254, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 254, 254, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 127, 127, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 125, 125, 32)   │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 62, 62, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 60, 60, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 28, 28, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling2d_1          │ (None, 128)            │             0 │
# │ (GlobalMaxPooling2D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 131,299 (512.89 KB)
#  Trainable params: 131,267 (512.76 KB)
#  Non-trainable params: 32 (128.00 B)

# %% [markdown]
# ## Training the Model

# %% [markdown]
# ### Util Methods

# %%
# Dynamic Learning Rate
def lr_schedule(epoch):
    initial_lr = 0.001
    drop = 0.1
    epochs_drop = 5
    lr = initial_lr * np.power(drop, np.floor((1 + epoch) 
                                              / epochs_drop))
    return lr

# %%
# 5. Changing Learning Rate.
# 6. Changing Optimizers.
EPOCHS = 30
lr_scheduler = keras.callbacks.LearningRateScheduler(lr_schedule)
callbacks = [
    # keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=3, 
    #                                   monitor="val_accuracy"),
    # keras.callbacks.EarlyStopping(patience=5),
    keras.callbacks.LearningRateScheduler(lr_schedule),
]

cnn = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=EPOCHS,  
    callbacks=callbacks,
)
# Out:
# Epoch 1/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 107ms/step - accuracy: 0.3471 - loss: 1.1822 - val_accuracy: 0.3673 - val_loss: 1.0968 - learning_rate: 0.0010
# Epoch 2/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.3726 - loss: 1.0935 - val_accuracy: 0.3724 - val_loss: 1.0927 - learning_rate: 0.0010
# Epoch 3/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.3515 - loss: 1.0975 - val_accuracy: 0.3367 - val_loss: 1.0901 - learning_rate: 0.0010
# Epoch 4/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 124ms/step - accuracy: 0.4167 - loss: 1.0587 - val_accuracy: 0.3878 - val_loss: 1.0823 - learning_rate: 0.0010
# Epoch 5/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 106ms/step - accuracy: 0.4968 - loss: 1.0056 - val_accuracy: 0.3878 - val_loss: 1.0742 - learning_rate: 1.0000e-04
# Epoch 6/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - accuracy: 0.5327 - loss: 0.9732 - val_accuracy: 0.3776 - val_loss: 1.0634 - learning_rate: 1.0000e-04
# Epoch 7/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 107ms/step - accuracy: 0.5335 - loss: 0.9530 - val_accuracy: 0.3776 - val_loss: 1.0576 - learning_rate: 1.0000e-04
# Epoch 8/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.5562 - loss: 0.9363 - val_accuracy: 0.3878 - val_loss: 1.0521 - learning_rate: 1.0000e-04
# Epoch 9/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - accuracy: 0.5637 - loss: 0.9028 - val_accuracy: 0.4541 - val_loss: 1.0244 - learning_rate: 1.0000e-04
# Epoch 10/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.5952 - loss: 0.8664 - val_accuracy: 0.4643 - val_loss: 1.0152 - learning_rate: 1.0000e-05
# Epoch 11/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.6194 - loss: 0.8695 - val_accuracy: 0.4898 - val_loss: 1.0079 - learning_rate: 1.0000e-05
# Epoch 12/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.6049 - loss: 0.8683 - val_accuracy: 0.4898 - val_loss: 1.0042 - learning_rate: 1.0000e-05
# Epoch 13/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.6049 - loss: 0.8750 - val_accuracy: 0.5102 - val_loss: 1.0038 - learning_rate: 1.0000e-05
# Epoch 14/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.5980 - loss: 0.8611 - val_accuracy: 0.4847 - val_loss: 1.0076 - learning_rate: 1.0000e-05
# Epoch 15/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.6537 - loss: 0.8478 - val_accuracy: 0.4796 - val_loss: 1.0117 - learning_rate: 1.0000e-06
# Epoch 16/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.6053 - loss: 0.8713 - val_accuracy: 0.4694 - val_loss: 1.0158 - learning_rate: 1.0000e-06
# Epoch 17/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.6111 - loss: 0.8610 - val_accuracy: 0.4694 - val_loss: 1.0187 - learning_rate: 1.0000e-06
# Epoch 18/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 107ms/step - accuracy: 0.5951 - loss: 0.8664 - val_accuracy: 0.4745 - val_loss: 1.0206 - learning_rate: 1.0000e-06
# Epoch 19/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 106ms/step - accuracy: 0.6192 - loss: 0.8485 - val_accuracy: 0.4796 - val_loss: 1.0222 - learning_rate: 1.0000e-06
# Epoch 20/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - accuracy: 0.6307 - loss: 0.8488 - val_accuracy: 0.4694 - val_loss: 1.0233 - learning_rate: 1.0000e-07
# Epoch 21/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 124ms/step - accuracy: 0.6255 - loss: 0.8651 - val_accuracy: 0.4643 - val_loss: 1.0237 - learning_rate: 1.0000e-07
# Epoch 22/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.6109 - loss: 0.8709 - val_accuracy: 0.4745 - val_loss: 1.0243 - learning_rate: 1.0000e-07
# Epoch 23/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.5968 - loss: 0.8766 - val_accuracy: 0.4796 - val_loss: 1.0244 - learning_rate: 1.0000e-07
# Epoch 24/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.6188 - loss: 0.8522 - val_accuracy: 0.4796 - val_loss: 1.0248 - learning_rate: 1.0000e-07
# Epoch 25/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 124ms/step - accuracy: 0.6077 - loss: 0.8582 - val_accuracy: 0.4796 - val_loss: 1.0251 - learning_rate: 1.0000e-08
# Epoch 26/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.6308 - loss: 0.8500 - val_accuracy: 0.4796 - val_loss: 1.0250 - learning_rate: 1.0000e-08
# Epoch 27/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 124ms/step - accuracy: 0.6392 - loss: 0.8426 - val_accuracy: 0.4694 - val_loss: 1.0254 - learning_rate: 1.0000e-08
# Epoch 28/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.6187 - loss: 0.8514 - val_accuracy: 0.4745 - val_loss: 1.0252 - learning_rate: 1.0000e-08
# Epoch 29/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.5907 - loss: 0.8592 - val_accuracy: 0.4796 - val_loss: 1.0252 - learning_rate: 1.0000e-08
# Epoch 30/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.6544 - loss: 0.8470 - val_accuracy: 0.4796 - val_loss: 1.0252 - learning_rate: 1.0000e-09

# %% [markdown]
# ## Evaluation of the Model

# %% [markdown]
# ### Predicting a specific Image

# %%
img_path = (
    "hair_types/Curly_Hair/02dac897d1dec9ba8c057a11d041ada8--" +
    "layered-natural-hair-natural-black-hairstyles.jpg"
)
img = tf.keras.preprocessing.image.load_img(img_path, 
                                            target_size=(HEIGHT, WIDTH))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

# Predict probabilities
predictions = model.predict(img_array)[0]  

# Scale predictions to percentages
total_percentage = sum(predictions)
scaled_predictions = [p * 100 / total_percentage for p in predictions]

class_names = ["Curly Hair", "Straight Hair", "Wavy Hair"]  
percentage_str = ", ".join(["%.2f percent %s" % (p, class_names[i]) for i, 
                            p in enumerate(scaled_predictions)])
print("This image is " + percentage_str + ".")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# This image is 54.77 percent Curly Hair, 23.16 percent Straight Hair, 22.07 percent Wavy Hair.

# %% [markdown]
# ### Predicting a Random Image

# %%
import os
import random
folder_number = random.randint(1, 3)  # Generate a random number between 1-3
if folder_number == 1:
    dataset_dir = "hair_types/Curly_Hair/"
elif folder_number == 2:
    dataset_dir = "hair_types/Straight_Hair/"
else:
    dataset_dir = "hair_types/Wavy_Hair/"

print(dataset_dir)
file_list = os.listdir(dataset_dir)

random_file = random.choice(file_list)
print(random_file)
image_path = os.path.join(dataset_dir, random_file)

img = tf.keras.preprocessing.image.load_img(image_path, 
                                            target_size=(HEIGHT, WIDTH))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

# Make predictions
predictions = model.predict(img_array)[0]


# Scale predictions to percentages
total_percentage = sum(predictions)
scaled_predictions = [p * 100 / total_percentage for p in predictions]

class_names = ["Curly Hair", "Straight Hair", "Wavy Hair"]  
percentage_str = ", ".join(["%.2f percent %s" % (p, class_names[i]) for i, 
                            p in enumerate(scaled_predictions)])
print("This image is " + percentage_str + ".")
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# hair_types/Wavy_Hair/
# images258.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# This image is 6.81 percent Curly Hair, 62.63 percent Straight Hair, 30.55 percent Wavy Hair.

# %% [markdown]
# ### Visualization in Respect to Epochs

# %%
acc = cnn.history['accuracy']
val_acc = cnn.history['val_accuracy']

loss = cnn.history['loss']
val_loss = cnn.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
