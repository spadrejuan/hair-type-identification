# %% [markdown]
# # The Source Code for Lab Exercise 3.
# ## Steps
# 1. Preprocess the Data.
# 2. Create a Train and Test Split
# 3. Create a Convolutional Neural Network using Keras.
# 4. Experiment on Various Elements
# 5. Discussion and Analysis of Experiments.

# %% [markdown]
# # Possible Things to Experiment on
# 1. Other Preprocessing methods for Images.
# 2. Adding Max Pooling.
# 3. Changing number of Filters.
# 4. Changing Kernel Size.
# 5. Changing Learning Rate.
# 6. Changing Optimizers.

# %% [markdown]
# ### Check Keras and Tensforflow Version and check for GPU compatibilities

# %%
import sys
import tensorflow as tf
import keras
import platform

print(f"Python Platform: {platform.version()}")
print(f"Python Version: {sys.version}")
print(f"Tensorflow version: {tf.__version__}")
print(f"Keras version: {keras.__version__}")
print()
gpu = len(tf.config.list_physical_devices('GPU')) > 0
print(f"GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# Python Platform: Darwin Kernel Version 23.4.0: Fri Mar 15 00:19:22 PDT 2024; root:xnu-10063.101.17~1/RELEASE_ARM64_T8112
# Python Version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:51:49) [Clang 16.0.6 ]
# Tensorflow version: 2.16.1
# Keras version: 3.2.1
#
# GPU is available

# %% [markdown]
# ### Checking for Invalid datasets

# %%
from pathlib import Path
import imghdr
import os

DATA_DIR = "hair_types"
IMAGE_EXTENSIONS = [".png", ".jpg"]  # add there all your images file extensions

img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]
for filepath in Path(DATA_DIR).rglob("*"):
    if filepath.suffix.lower() in IMAGE_EXTENSIONS:
        img_type = imghdr.what(filepath)
        if img_type is None:
            print(f"{filepath} is not an image")
            os.remove(filepath)
        elif img_type not in img_type_accepted_by_tf:
            print(f"{filepath} is a {img_type}, not accepted by TensorFlow")
            os.remove(filepath)

# %% [markdown]
# ## Preprocessing Images Section

# %% [markdown]
# ### Import Tensorflow and Keras

# %%
import tensorflow as tf
import keras # we define like this for IntelliSense

# We define the constants for our images
BATCH_SIZE = 16
HEIGHT = 256
WIDTH = 256
IMAGE_SIZE = (HEIGHT, WIDTH)

# %% [markdown]
# ### Loading Datasets for the Validation and Training splits

# %%
train_dataset = keras.preprocessing.image_dataset_from_directory(
    directory="hair_types",
    batch_size=BATCH_SIZE,
    image_size=IMAGE_SIZE,
    seed=1337, # same as Demo
    validation_split=0.2, # use 20% as validation
    subset="training",
    label_mode="categorical"
)
val_dataset = keras.preprocessing.image_dataset_from_directory(
    directory="hair_types",
    batch_size=BATCH_SIZE,
    image_size=IMAGE_SIZE,
    seed=1337, # same as Demo
    validation_split=0.2, # use 20% as validation
    subset="validation",
    label_mode="categorical"
)
# The target labels
class_names = train_dataset.class_names
print(class_names)
# Out:
# Found 981 files belonging to 3 classes.
# Using 785 files for training.
# Found 981 files belonging to 3 classes.
# Using 196 files for validation.
# ['Curly_Hair', 'Straight_Hair', 'Wavy_Hair']
# 2024-04-28 22:25:04.840329: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2024-04-28 22:25:04.840348: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2024-04-28 22:25:04.840356: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2024-04-28 22:25:04.840371: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-04-28 22:25:04.840388: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ### Visualizing the initial dataset

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[np.argmax(labels[i])])
    plt.axis("off")
# Out:
# 2024-04-28 22:25:05.551980: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ### Ways to Preprocess Images - Data Augmentation using keras.Layers

# %%
from keras import layers # We import like this for IntelliSense
data_augmentation_methods = keras.Sequential([
   layers.RandomFlip('horizontal_and_vertical'),
   layers.RandomRotation(factor=0.8),
   layers.RandomBrightness(factor=0.2),
   layers.RandomTranslation(height_factor=0.2, width_factor=0.2),  
   # Shift within 20% of image size
   layers.RandomZoom(height_factor=0.2, width_factor=0.2),
   layers.RandomContrast(factor=0.4),
])

# %% [markdown]
# ### Visualizing how these methods affect images

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
    for i in range(9):
        augmented_images = data_augmentation_methods(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(np.array(augmented_images[0]).astype("uint8"))
        plt.axis("off")
plt.show()
# Out:
# 2024-04-28 22:25:06.874998: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ### GPU Optimization

# %%
from tensorflow import data as tf_data
# Configuring dataset for performance
# Prefetching samples in GPU memory helps maximize GPU utilization.
train_dataset = train_dataset.prefetch(tf_data.AUTOTUNE)
val_dataset = val_dataset.prefetch(tf_data.AUTOTUNE)

# %% [markdown]
# ## Creating a Convolutional Neural Network using Keras

# %%
# 2. Adding Max Pooling.
# 3. Changing number of Filters.
# 4. Changing Kernel Size.
from keras import regularizers
model = keras.models.Sequential()

# Preprocessing Layer
model.add(keras.Input(shape=IMAGE_SIZE + (3,)))
model.add(layers.Rescaling(1.0 / 255))

# Convolutional Layer
# model.add(layers.Conv2D(filters=16, kernel_size=(3, 3), activation='relu'))

model.add(layers.Conv2D(filters=32, kernel_size=(3, 3), strides=1, padding="valid", dilation_rate=1, activation='relu'))
model.add(layers.Dropout(0.3))
model.add(layers.MaxPooling2D(pool_size=(2,2)))

model.add(layers.Conv2D(filters=64, kernel_size=(3,3), strides=1, padding="valid", dilation_rate=1, activation="relu"))
model.add(layers.Dropout(0.3))
model.add(layers.MaxPooling2D(pool_size=(2,2)))

model.add(layers.Conv2D(filters=128, kernel_size=(3,3), strides=1, padding="valid", dilation_rate=1, activation="relu"))
model.add(layers.Dropout(0.3))
model.add(layers.MaxPooling2D(pool_size=(2,2)))

# Output Layer
model.add(layers.Flatten())

model.add(layers.Dense(units=256, activation="relu")) 
model.add(layers.Dropout(0.3))

model.add(layers.Dense(units=3, activation="softmax"))


# Compile the model
model.compile(
    optimizer=keras.optimizers.Adam(0.001),
    loss=keras.losses.CategoricalCrossentropy(),
    metrics=['accuracy'],
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 254, 254, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 254, 254, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 127, 127, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 125, 125, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 125, 125, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 60, 60, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 60, 60, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 30, 30, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 115200)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │    29,491,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,585,475 (112.86 MB)
#  Trainable params: 29,585,475 (112.86 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training the Model

# %% [markdown]
# ### Util Methods

# %%
# Dynamic Learning Rate
def lr_schedule(epoch):
    initial_lr = 0.0001
    drop = 0.1
    epochs_drop = 8
    lr = initial_lr * np.power(drop, np.floor((1 + epoch) 
                                              / epochs_drop))
    return lr

# %%
# 5. Changing Learning Rate.
# 6. Changing Optimizers.
EPOCHS = 50
stop = keras.callbacks.EarlyStopping(patience=8, monitor="val_loss", start_from_epoch=16, verbose=1)
callbacks = [
    stop,
    keras.callbacks.LearningRateScheduler(lr_schedule),
]

cnn = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=EPOCHS,  
    callbacks=callbacks,
)
# Out:
# Epoch 1/50
# 2024-04-28 22:25:07.601525: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 187ms/step - accuracy: 0.3792 - loss: 1.3107 - val_accuracy: 0.5408 - val_loss: 1.0706 - learning_rate: 1.0000e-04
# Epoch 2/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 180ms/step - accuracy: 0.5792 - loss: 0.9589 - val_accuracy: 0.5102 - val_loss: 1.0028 - learning_rate: 1.0000e-04
# Epoch 3/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 166ms/step - accuracy: 0.6163 - loss: 0.8416 - val_accuracy: 0.5306 - val_loss: 0.9759 - learning_rate: 1.0000e-04
# Epoch 4/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 174ms/step - accuracy: 0.7818 - loss: 0.6172 - val_accuracy: 0.5714 - val_loss: 0.9457 - learning_rate: 1.0000e-04
# Epoch 5/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 180ms/step - accuracy: 0.7797 - loss: 0.5715 - val_accuracy: 0.5918 - val_loss: 0.9011 - learning_rate: 1.0000e-04
# Epoch 6/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 173ms/step - accuracy: 0.8546 - loss: 0.3913 - val_accuracy: 0.6020 - val_loss: 0.8954 - learning_rate: 1.0000e-04
# Epoch 7/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 166ms/step - accuracy: 0.8936 - loss: 0.3037 - val_accuracy: 0.5867 - val_loss: 0.9053 - learning_rate: 1.0000e-04
# Epoch 8/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 180ms/step - accuracy: 0.9463 - loss: 0.2036 - val_accuracy: 0.6122 - val_loss: 0.8731 - learning_rate: 1.0000e-05
# Epoch 9/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 197ms/step - accuracy: 0.9585 - loss: 0.1698 - val_accuracy: 0.6173 - val_loss: 0.8691 - learning_rate: 1.0000e-05
# Epoch 10/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 192ms/step - accuracy: 0.9547 - loss: 0.1758 - val_accuracy: 0.6173 - val_loss: 0.8696 - learning_rate: 1.0000e-05
# Epoch 11/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 181ms/step - accuracy: 0.9730 - loss: 0.1489 - val_accuracy: 0.6173 - val_loss: 0.8738 - learning_rate: 1.0000e-05
# Epoch 12/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 195ms/step - accuracy: 0.9750 - loss: 0.1338 - val_accuracy: 0.5969 - val_loss: 0.8660 - learning_rate: 1.0000e-05
# Epoch 13/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.9722 - loss: 0.1418 - val_accuracy: 0.6122 - val_loss: 0.8664 - learning_rate: 1.0000e-05
# Epoch 14/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 182ms/step - accuracy: 0.9724 - loss: 0.1291 - val_accuracy: 0.6122 - val_loss: 0.8700 - learning_rate: 1.0000e-05
# Epoch 15/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 0.9835 - loss: 0.1133 - val_accuracy: 0.6020 - val_loss: 0.8747 - learning_rate: 1.0000e-05
# Epoch 16/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 208ms/step - accuracy: 0.9849 - loss: 0.1090 - val_accuracy: 0.6020 - val_loss: 0.8756 - learning_rate: 1.0000e-06
# Epoch 17/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 269ms/step - accuracy: 0.9728 - loss: 0.1169 - val_accuracy: 0.6071 - val_loss: 0.8747 - learning_rate: 1.0000e-06
# Epoch 18/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 286ms/step - accuracy: 0.9864 - loss: 0.1142 - val_accuracy: 0.6071 - val_loss: 0.8794 - learning_rate: 1.0000e-06
# Epoch 19/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 173ms/step - accuracy: 0.9747 - loss: 0.1193 - val_accuracy: 0.6071 - val_loss: 0.8766 - learning_rate: 1.0000e-06
# Epoch 20/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 193ms/step - accuracy: 0.9830 - loss: 0.1034 - val_accuracy: 0.6122 - val_loss: 0.8763 - learning_rate: 1.0000e-06
# Epoch 21/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 195ms/step - accuracy: 0.9834 - loss: 0.0992 - val_accuracy: 0.6071 - val_loss: 0.8779 - learning_rate: 1.0000e-06
# Epoch 22/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 182ms/step - accuracy: 0.9710 - loss: 0.1113 - val_accuracy: 0.6122 - val_loss: 0.8736 - learning_rate: 1.0000e-06
# Epoch 23/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 184ms/step - accuracy: 0.9777 - loss: 0.1128 - val_accuracy: 0.6020 - val_loss: 0.8742 - learning_rate: 1.0000e-06
# Epoch 24/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.9849 - loss: 0.1056 - val_accuracy: 0.6071 - val_loss: 0.8745 - learning_rate: 1.0000e-07
# Epoch 25/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 181ms/step - accuracy: 0.9880 - loss: 0.0953 - val_accuracy: 0.6071 - val_loss: 0.8750 - learning_rate: 1.0000e-07
# Epoch 26/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.9844 - loss: 0.0987 - val_accuracy: 0.6071 - val_loss: 0.8753 - learning_rate: 1.0000e-07
# Epoch 27/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 189ms/step - accuracy: 0.9853 - loss: 0.1105 - val_accuracy: 0.6071 - val_loss: 0.8755 - learning_rate: 1.0000e-07
# Epoch 28/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 218ms/step - accuracy: 0.9781 - loss: 0.1082 - val_accuracy: 0.6071 - val_loss: 0.8754 - learning_rate: 1.0000e-07
# Epoch 29/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 213ms/step - accuracy: 0.9871 - loss: 0.1035 - val_accuracy: 0.6071 - val_loss: 0.8756 - learning_rate: 1.0000e-07
# Epoch 30/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 13s 242ms/step - accuracy: 0.9805 - loss: 0.1092 - val_accuracy: 0.6071 - val_loss: 0.8755 - learning_rate: 1.0000e-07
# Epoch 30: early stopping

# %% [markdown]
# ## Evaluation of the Model

# %% [markdown]
# ### Predicting a specific Image

# %%
img_path = (
    "hair_types/Curly_Hair/02dac897d1dec9ba8c057a11d041ada8--" +
    "layered-natural-hair-natural-black-hairstyles.jpg"
)

img = tf.keras.preprocessing.image.load_img(img_path, 
                                            target_size=(HEIGHT, WIDTH))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

# Predict probabilities
predictions = model.predict(img_array)[0]  

# Scale predictions to percentages
total_percentage = sum(predictions)
scaled_predictions = [p * 100 / total_percentage for p in predictions]

class_names = ["Curly Hair", "Straight Hair", "Wavy Hair"]  
percentage_str = ", ".join(["%.2f percent %s" % (p, class_names[i]) for i, 
                            p in enumerate(scaled_predictions)])
print("This image is " + percentage_str + ".")
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step
# This image is 88.80 percent Curly Hair, 6.93 percent Straight Hair, 4.27 percent Wavy Hair.

# %% [markdown]
# ### Predicting a Random Image

# %%
import os
import random
folder_number = random.randint(1, 3)  # Generate a random number between 1-3
if folder_number == 1:
    dataset_dir = "hair_types/Curly_Hair/"
elif folder_number == 2:
    dataset_dir = "hair_types/Straight_Hair/"
else:
    dataset_dir = "hair_types/Wavy_Hair/"

print(dataset_dir)
file_list = os.listdir(dataset_dir)

random_file = random.choice(file_list)
print(random_file)
image_path = os.path.join(dataset_dir, random_file)

img = tf.keras.preprocessing.image.load_img(image_path, 
                                            target_size=(HEIGHT, WIDTH))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

# Make predictions
predictions = model.predict(img_array)[0]


# Scale predictions to percentages
total_percentage = sum(predictions)
scaled_predictions = [p * 100 / total_percentage for p in predictions]

class_names = ["Curly Hair", "Straight Hair", "Wavy Hair"]  
percentage_str = ", ".join(["%.2f percent %s" % (p, class_names[i]) for i, 
                            p in enumerate(scaled_predictions)])
print("This image is " + percentage_str + ".")
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# hair_types/Straight_Hair/
# 8.-Messy-Tousled-Hairstyle-for-Men.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# This image is 34.51 percent Curly Hair, 55.26 percent Straight Hair, 10.23 percent Wavy Hair.

# %% [markdown]
# ### Visualization in Respect to Epochs

# %%
acc = cnn.history['accuracy']
val_acc = cnn.history['val_accuracy']

loss = cnn.history['loss']
val_loss = cnn.history['val_loss']
if stop.stopped_epoch != 0:
    epochs_range = range(stop.stopped_epoch+1)
else:
    epochs_range = range(EPOCHS)
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
