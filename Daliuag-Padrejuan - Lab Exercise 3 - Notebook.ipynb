# %% [markdown]
# # The Source Code for Lab Exercise 3.
# ## Steps
# 1. Preprocess the Data.
# 2. Create a Train and Test Split
# 3. Create a Convolutional Neural Network using Keras.
# 4. Experiment on Various Elements
# 5. Discussion and Analysis of Experiments.

# %% [markdown]
# # Possible Things to Experiment on
# 1. Other Preprocessing methods for Images.
# 2. Adding Max Pooling.
# 3. Changing number of Filters.
# 4. Changing Kernel Size.
# 5. Changing Learning Rate.
# 6. Changing Optimizers.

# %% [markdown]
# ### Check Keras and Tensforflow Version and check for GPU compatibilities

# %%
import sys
import tensorflow as tf
import keras
import platform

print(f"Python Platform: {platform.version()}")
print(f"Python Version: {sys.version}")
print(f"Tensorflow version: {tf.__version__}")
print(f"Keras version: {keras.__version__}")
print()
gpu = len(tf.config.list_physical_devices('GPU')) > 0
print(f"GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# Python Platform: Darwin Kernel Version 23.4.0: Fri Mar 15 00:19:22 PDT 2024; root:xnu-10063.101.17~1/RELEASE_ARM64_T8112
# Python Version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:51:49) [Clang 16.0.6 ]
# Tensorflow version: 2.16.1
# Keras version: 3.2.1
#
# GPU is available

# %% [markdown]
# ### Checking for Invalid datasets

# %%
from pathlib import Path
import imghdr
import os

DATA_DIR = "hair_types"
IMAGE_EXTENSIONS = [".png", ".jpg"]  # add there all your images file extensions

img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]
for filepath in Path(DATA_DIR).rglob("*"):
    if filepath.suffix.lower() in IMAGE_EXTENSIONS:
        img_type = imghdr.what(filepath)
        if img_type is None:
            print(f"{filepath} is not an image")
            os.remove(filepath)
        elif img_type not in img_type_accepted_by_tf:
            print(f"{filepath} is a {img_type}, not accepted by TensorFlow")
            os.remove(filepath)

# %% [markdown]
# ## Preprocessing Images Section

# %% [markdown]
# ### Import Tensorflow and Keras

# %%
import tensorflow as tf
import keras # we define like this for IntelliSense

# We define the constants for our images
BATCH_SIZE = 16
HEIGHT = 256
WIDTH = 256
IMAGE_SIZE = (HEIGHT, WIDTH)

# %% [markdown]
# ### Loading Datasets for the Validation and Training splits

# %%
train_dataset = keras.preprocessing.image_dataset_from_directory(
    directory="hair_types",
    batch_size=BATCH_SIZE,
    image_size=IMAGE_SIZE,
    seed=1337, # same as Demo
    validation_split=0.2, # use 20% as validation
    subset="training",
    label_mode="categorical"
)
val_dataset = keras.preprocessing.image_dataset_from_directory(
    directory="hair_types",
    batch_size=BATCH_SIZE,
    image_size=IMAGE_SIZE,
    seed=1337, # same as Demo
    validation_split=0.2, # use 20% as validation
    subset="validation",
    label_mode="categorical"
)
# The target labels
class_names = train_dataset.class_names
print(class_names)
# Out:
# Found 981 files belonging to 3 classes.
# Using 785 files for training.
# Found 981 files belonging to 3 classes.
# Using 196 files for validation.
# ['Curly_Hair', 'Straight_Hair', 'Wavy_Hair']

# %% [markdown]
# ### Visualizing the initial dataset

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[np.argmax(labels[i])])
    plt.axis("off")
# Out:
# 2024-04-27 12:14:10.571914: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ### Ways to Preprocess Images - Data Augmentation using keras.Layers

# %%
from keras import layers # We import like this for IntelliSense
data_augmentation_methods = keras.Sequential([
   layers.RandomFlip('horizontal_and_vertical'),
   layers.RandomRotation(factor=0.8),
   layers.RandomBrightness(factor=0.2),
   #layers.RandomTranslation(height_factor=0.2, width_factor=0.2),  
   # Shift within 20% of image size
   #layers.RandomZoom(height_factor=0.2, width_factor=0.2),
   layers.RandomContrast(factor=0.4),
])

# %% [markdown]
# ### Visualizing how these methods affect images

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
    for i in range(9):
        augmented_images = data_augmentation_methods(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(np.array(augmented_images[0]).astype("uint8"))
        plt.axis("off")
plt.show()
# Out:
# 2024-04-27 12:14:11.532977: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ### GPU Optimization

# %%
from tensorflow import data as tf_data
# Configuring dataset for performance
# Prefetching samples in GPU memory helps maximize GPU utilization.
train_dataset = train_dataset.prefetch(tf_data.AUTOTUNE)
val_dataset = val_dataset.prefetch(tf_data.AUTOTUNE)

# %% [markdown]
# ## Creating a Convolutional Neural Network using Keras

# %%
# 2. Adding Max Pooling.
# 3. Changing number of Filters.
# 4. Changing Kernel Size.
from keras import regularizers
model = keras.models.Sequential()

# Preprocessing Layer
model.add(keras.Input(shape=IMAGE_SIZE + (3,)))
model.add(layers.Rescaling(1.0 / 255))

# Convolutional Layer
model.add(layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
model.add(layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
model.add(layers.MaxPooling2D(pool_size=(2,2)))

model.add(layers.Conv2D(filters=64, kernel_size=(3,3), activation="relu"))
model.add(layers.Conv2D(filters=64, kernel_size=(3,3), activation="relu"))
model.add(layers.MaxPooling2D(pool_size=(2,2)))

model.add(layers.Conv2D(filters=128, kernel_size=(3,3), activation="relu"))
model.add(layers.Conv2D(filters=128, kernel_size=(3,3), activation="relu"))
model.add(layers.MaxPooling2D(pool_size=(2,2)))

# Output Layer
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Flatten())

model.add(layers.Dense(units=512, activation="relu"))

model.add(layers.Dense(units=3, activation="softmax"))


# Compile the model
model.compile(
    optimizer=keras.optimizers.Adam(0.001),
    loss=keras.losses.CategoricalCrossentropy(),
    metrics=['accuracy'],
)

model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_1 (Rescaling)         │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 254, 254, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 252, 252, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 126, 126, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 124, 124, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 122, 122, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 61, 61, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 59, 59, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 57, 57, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 3)              │         1,539 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 354,595 (1.35 MB)
#  Trainable params: 354,595 (1.35 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training the Model

# %% [markdown]
# ### Util Methods

# %%
# Dynamic Learning Rate
def lr_schedule(epoch):
    initial_lr = 0.001
    drop = 0.1
    epochs_drop = 5
    lr = initial_lr * np.power(drop, np.floor((1 + epoch) 
                                              / epochs_drop))
    return lr

# %%
# 5. Changing Learning Rate.
# 6. Changing Optimizers.
EPOCHS = 50
stop = keras.callbacks.EarlyStopping(patience=8, restore_best_weights=True, monitor="val_loss", start_from_epoch=10)
lr_scheduler = keras.callbacks.LearningRateScheduler(lr_schedule)
callbacks = [
    # keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=3, 
    #                                   monitor="val_accuracy"),
    stop,
    keras.callbacks.LearningRateScheduler(lr_schedule),
]

cnn = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=EPOCHS,  
    callbacks=callbacks,
)
# Out:
# Epoch 1/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 178ms/step - accuracy: 0.3062 - loss: 1.1021 - val_accuracy: 0.2857 - val_loss: 1.1006 - learning_rate: 0.0010
# Epoch 2/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 184ms/step - accuracy: 0.3527 - loss: 1.0982 - val_accuracy: 0.2857 - val_loss: 1.1074 - learning_rate: 0.0010
# Epoch 3/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 199ms/step - accuracy: 0.3124 - loss: 1.1011 - val_accuracy: 0.2857 - val_loss: 1.0995 - learning_rate: 0.0010
# Epoch 4/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 173ms/step - accuracy: 0.3396 - loss: 1.0984 - val_accuracy: 0.2857 - val_loss: 1.1007 - learning_rate: 0.0010
# Epoch 5/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 175ms/step - accuracy: 0.3672 - loss: 1.0841 - val_accuracy: 0.2908 - val_loss: 1.0969 - learning_rate: 1.0000e-04
# Epoch 6/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 177ms/step - accuracy: 0.3553 - loss: 1.0814 - val_accuracy: 0.2857 - val_loss: 1.0934 - learning_rate: 1.0000e-04
# Epoch 7/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 172ms/step - accuracy: 0.3547 - loss: 1.0779 - val_accuracy: 0.3622 - val_loss: 1.0840 - learning_rate: 1.0000e-04
# Epoch 8/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 175ms/step - accuracy: 0.3730 - loss: 1.0693 - val_accuracy: 0.3724 - val_loss: 1.0738 - learning_rate: 1.0000e-04
# Epoch 9/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 171ms/step - accuracy: 0.4198 - loss: 1.0431 - val_accuracy: 0.5051 - val_loss: 1.0525 - learning_rate: 1.0000e-04
# Epoch 10/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 170ms/step - accuracy: 0.4804 - loss: 1.0431 - val_accuracy: 0.4796 - val_loss: 1.0523 - learning_rate: 1.0000e-05
# Epoch 11/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 176ms/step - accuracy: 0.4945 - loss: 1.0278 - val_accuracy: 0.4694 - val_loss: 1.0520 - learning_rate: 1.0000e-05
# Epoch 12/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 160ms/step - accuracy: 0.4871 - loss: 1.0306 - val_accuracy: 0.4745 - val_loss: 1.0523 - learning_rate: 1.0000e-05
# Epoch 13/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - accuracy: 0.4701 - loss: 1.0319 - val_accuracy: 0.4694 - val_loss: 1.0505 - learning_rate: 1.0000e-05
# Epoch 14/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - accuracy: 0.4848 - loss: 1.0211 - val_accuracy: 0.4694 - val_loss: 1.0497 - learning_rate: 1.0000e-05
# Epoch 15/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 170ms/step - accuracy: 0.4847 - loss: 1.0174 - val_accuracy: 0.4694 - val_loss: 1.0496 - learning_rate: 1.0000e-06
# Epoch 16/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 164ms/step - accuracy: 0.4816 - loss: 1.0206 - val_accuracy: 0.4745 - val_loss: 1.0497 - learning_rate: 1.0000e-06
# Epoch 17/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 162ms/step - accuracy: 0.4750 - loss: 1.0246 - val_accuracy: 0.4694 - val_loss: 1.0495 - learning_rate: 1.0000e-06
# Epoch 18/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - accuracy: 0.4706 - loss: 1.0234 - val_accuracy: 0.4694 - val_loss: 1.0496 - learning_rate: 1.0000e-06
# Epoch 19/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 161ms/step - accuracy: 0.4815 - loss: 1.0219 - val_accuracy: 0.4694 - val_loss: 1.0495 - learning_rate: 1.0000e-06
# Epoch 20/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - accuracy: 0.4724 - loss: 1.0280 - val_accuracy: 0.4694 - val_loss: 1.0495 - learning_rate: 1.0000e-07
# Epoch 21/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - accuracy: 0.4721 - loss: 1.0186 - val_accuracy: 0.4694 - val_loss: 1.0495 - learning_rate: 1.0000e-07
# Epoch 22/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 162ms/step - accuracy: 0.4786 - loss: 1.0215 - val_accuracy: 0.4694 - val_loss: 1.0495 - learning_rate: 1.0000e-07
# Epoch 23/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 160ms/step - accuracy: 0.4575 - loss: 1.0286 - val_accuracy: 0.4694 - val_loss: 1.0495 - learning_rate: 1.0000e-07
# Epoch 24/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 161ms/step - accuracy: 0.4841 - loss: 1.0174 - val_accuracy: 0.4694 - val_loss: 1.0495 - learning_rate: 1.0000e-07
# Epoch 25/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 158ms/step - accuracy: 0.4766 - loss: 1.0264 - val_accuracy: 0.4694 - val_loss: 1.0495 - learning_rate: 1.0000e-08

# %% [markdown]
# ## Evaluation of the Model

# %% [markdown]
# ### Predicting a specific Image

# %%
img_path = (
    "hair_types/Curly_Hair/02dac897d1dec9ba8c057a11d041ada8--" +
    "layered-natural-hair-natural-black-hairstyles.jpg"
)

img = tf.keras.preprocessing.image.load_img(img_path, 
                                            target_size=(HEIGHT, WIDTH))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

# Predict probabilities
predictions = model.predict(img_array)[0]  

# Scale predictions to percentages
total_percentage = sum(predictions)
scaled_predictions = [p * 100 / total_percentage for p in predictions]

class_names = ["Curly Hair", "Straight Hair", "Wavy Hair"]  
percentage_str = ", ".join(["%.2f percent %s" % (p, class_names[i]) for i, 
                            p in enumerate(scaled_predictions)])
print("This image is " + percentage_str + ".")
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step
# This image is 73.64 percent Curly Hair, 10.63 percent Straight Hair, 15.73 percent Wavy Hair.

# %% [markdown]
# ### Predicting a Random Image

# %%
import os
import random
folder_number = random.randint(1, 3)  # Generate a random number between 1-3
if folder_number == 1:
    dataset_dir = "hair_types/Curly_Hair/"
elif folder_number == 2:
    dataset_dir = "hair_types/Straight_Hair/"
else:
    dataset_dir = "hair_types/Wavy_Hair/"

print(dataset_dir)
file_list = os.listdir(dataset_dir)

random_file = random.choice(file_list)
print(random_file)
image_path = os.path.join(dataset_dir, random_file)

img = tf.keras.preprocessing.image.load_img(image_path, 
                                            target_size=(HEIGHT, WIDTH))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

# Make predictions
predictions = model.predict(img_array)[0]


# Scale predictions to percentages
total_percentage = sum(predictions)
scaled_predictions = [p * 100 / total_percentage for p in predictions]

class_names = ["Curly Hair", "Straight Hair", "Wavy Hair"]  
percentage_str = ", ".join(["%.2f percent %s" % (p, class_names[i]) for i, 
                            p in enumerate(scaled_predictions)])
print("This image is " + percentage_str + ".")
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# hair_types/Curly_Hair/
# Kz_650x650-stylefeen-wash-day-.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# This image is 46.41 percent Curly Hair, 24.57 percent Straight Hair, 29.02 percent Wavy Hair.

# %% [markdown]
# ### Visualization in Respect to Epochs

# %%
acc = cnn.history['accuracy']
val_acc = cnn.history['val_accuracy']

loss = cnn.history['loss']
val_loss = cnn.history['val_loss']
if stop.stopped_epoch != 0:
    epochs_range = range(stop.stopped_epoch+1)
else:
    epochs_range = range(EPOCHS)
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
