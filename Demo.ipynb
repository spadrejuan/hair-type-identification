# %%
# !pip install tensorflow
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# Out:
# Requirement already satisfied: tensorflow in /Users/jjames/anaconda3/lib/python3.10/site-packages (2.12.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: jax>=0.3.15 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorflow) (0.4.19)
# Requirement already satisfied: six>=1.12.0 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: libclang>=13.0.0 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorflow) (2.12.3)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: setuptools in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorflow) (65.6.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorflow) (4.8.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorflow) (22.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorflow) (1.56.0)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from jax>=0.3.15->tensorflow) (0.3.1)
# Requirement already satisfied: scipy>=1.9 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from jax>=0.3.15->tensorflow) (1.10.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.2.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.30.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.23.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2022.12.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)
# Requirement already satisfied: numpy in /Users/jjames/anaconda3/lib/python3.10/site-packages (1.23.5)
# Requirement already satisfied: pandas in /Users/jjames/anaconda3/lib/python3.10/site-packages (2.0.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from pandas) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in /Users/jjames/anaconda3/lib/python3.10/site-packages (3.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from matplotlib) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: numpy>=1.20 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: cycler>=0.10 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in /Users/jjames/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
from pathlib import Path
import imghdr
import os

data_dir = "hair_types"
image_extensions = [".png", ".jpg"]  # add there all your images file extensions

img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]
for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        img_type = imghdr.what(filepath)
        if img_type is None:
            print(f"{filepath} is not an image")
            os.remove(filepath)
        elif img_type not in img_type_accepted_by_tf:
            print(f"{filepath} is a {img_type}, not accepted by TensorFlow")
            os.remove(filepath)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

image_size = (64, 64)
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types/",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels='inferred',
    label_mode='categorical'
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types/",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size, 
    labels='inferred',
    label_mode='categorical'
)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(np.argmax(labels[i])))
        plt.axis("off")
plt.show()

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(keras.Input(shape=image_size + (3,))) # 64, 64, 3
model.add(layers.Rescaling(1.0 / 255))

model.add(layers.Conv2D(filters=4, kernel_size=16, strides=1, padding='valid', dilation_rate=1))
model.add(layers.Activation("relu"))

model.add(layers.Conv2D(filters=8, kernel_size=8, strides=1, padding='valid', dilation_rate=1))
model.add(layers.Activation("relu"))

model.add(layers.Conv2D(filters=16, kernel_size=4, strides=1, padding='valid', dilation_rate=1))
model.add(layers.Activation("relu"))

model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dense(64))
model.add(layers.Activation("relu"))
model.add(layers.Dense(3))
model.add(layers.Activation("softmax"))

tf.keras.utils.plot_model(model, to_file='model_test.png', show_shapes=True)

epochs = 50

model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(train_ds, epochs=epochs, validation_data=val_ds)

# %%
img = keras.preprocessing.image.load_img(
    "hair_types/Curly_Hair/02dac897d1dec9ba8c057a11d041ada8--layered-natural-hair-natural-black-hairstyles.jpg", target_size=image_size
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

predictions = model.predict(img_array)
print(
    "This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions[0])
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 img = keras.preprocessing.image.load_img(
#       2     "hair_types/Curly_Hair/02dac897d1dec9ba8c057a11d041ada8--layered-natural-hair-natural-black-hairstyles.jpg", target_size=image_size
#       3 )
#       4 img_array = keras.preprocessing.image.img_to_array(img)
#       5 img_array = tf.expand_dims(img_array, 0)  # Create batch axis
#
# NameError: name 'keras' is not defined
