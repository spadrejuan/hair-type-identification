# %%
# !pip install tensorflow
# !pip install numpy
# !pip install pandas
# !pip install matplotlib

# %%
from pathlib import Path
import imghdr
import os

data_dir = "hair_types"
image_extensions = [".png", ".jpg"]  # add there all your images file extensions

img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]
for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        img_type = imghdr.what(filepath)
        if img_type is None:
            print(f"{filepath} is not an image")
            os.remove(filepath)
        elif img_type not in img_type_accepted_by_tf:
            print(f"{filepath} is a {img_type}, not accepted by TensorFlow")
            os.remove(filepath)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

image_size = (64, 64)
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types/",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels='inferred',
    label_mode='categorical'
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types/",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size, 
    labels='inferred',
    label_mode='categorical'
)
# Out:
# Found 985 files belonging to 3 classes.
# Using 788 files for training.
# Found 985 files belonging to 3 classes.
# Using 197 files for validation.

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(np.argmax(labels[i])))
        plt.axis("off")
plt.show()
# Out:
# 2024-04-09 09:32:22.234405: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [788]
# 	 [[{{node Placeholder/_4}}]]
# 2024-04-09 09:32:22.234761: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [788]
# 	 [[{{node Placeholder/_4}}]]

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(keras.Input(shape=image_size + (3,))) # 64, 64, 3
model.add(layers.Rescaling(1.0 / 255))

model.add(layers.Conv2D(filters=4, kernel_size=16, strides=1, padding='valid', dilation_rate=1))
model.add(layers.Activation("relu"))

model.add(layers.Conv2D(filters=8, kernel_size=8, strides=1, padding='valid', dilation_rate=1))
model.add(layers.Activation("relu"))

model.add(layers.Conv2D(filters=16, kernel_size=4, strides=1, padding='valid', dilation_rate=1))
model.add(layers.Activation("relu"))

model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dense(64))
model.add(layers.Activation("relu"))
model.add(layers.Dense(3))
model.add(layers.Activation("softmax"))

tf.keras.utils.plot_model(model, to_file='model_test.png', show_shapes=True)

epochs = 50

model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(train_ds, epochs=epochs, validation_data=val_ds)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/50
# 2024-04-09 09:32:23.148770: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [788]
# 	 [[{{node Placeholder/_4}}]]
# 2024-04-09 09:32:23.148962: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [788]
# 	 [[{{node Placeholder/_0}}]]
# 24/25 [===========================>..] - ETA: 0s - loss: 1.0993 - accuracy: 0.3138
# 2024-04-09 09:32:26.198688: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [197]
# 	 [[{{node Placeholder/_4}}]]
# 2024-04-09 09:32:26.198880: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [197]
# 	 [[{{node Placeholder/_4}}]]
# 25/25 [==============================] - 4s 115ms/step - loss: 1.0991 - accuracy: 0.3160 - val_loss: 1.0921 - val_accuracy: 0.4010
# Epoch 2/50
# 25/25 [==============================] - 3s 110ms/step - loss: 1.0931 - accuracy: 0.3896 - val_loss: 1.0808 - val_accuracy: 0.4061
# Epoch 3/50
# 25/25 [==============================] - 3s 107ms/step - loss: 1.0726 - accuracy: 0.4277 - val_loss: 1.0442 - val_accuracy: 0.4822
# Epoch 4/50
# 25/25 [==============================] - 3s 105ms/step - loss: 1.0297 - accuracy: 0.4518 - val_loss: 1.1334 - val_accuracy: 0.3503
# Epoch 5/50
# 25/25 [==============================] - 3s 109ms/step - loss: 1.0019 - accuracy: 0.5051 - val_loss: 1.0381 - val_accuracy: 0.4518
# Epoch 6/50
# 25/25 [==============================] - 3s 104ms/step - loss: 1.0089 - accuracy: 0.4734 - val_loss: 1.0476 - val_accuracy: 0.4518
# Epoch 7/50
# 25/25 [==============================] - 3s 107ms/step - loss: 0.9979 - accuracy: 0.5178 - val_loss: 1.0269 - val_accuracy: 0.4670
# Epoch 8/50
# 25/25 [==============================] - 3s 107ms/step - loss: 0.9848 - accuracy: 0.5152 - val_loss: 1.0612 - val_accuracy: 0.4416
# Epoch 9/50
# 25/25 [==============================] - 3s 106ms/step - loss: 1.0004 - accuracy: 0.5076 - val_loss: 1.0224 - val_accuracy: 0.4822
# Epoch 10/50
# 25/25 [==============================] - 3s 108ms/step - loss: 0.9595 - accuracy: 0.5470 - val_loss: 1.0326 - val_accuracy: 0.4467
# Epoch 11/50
# 25/25 [==============================] - 3s 109ms/step - loss: 0.9618 - accuracy: 0.5279 - val_loss: 1.0645 - val_accuracy: 0.4213
# Epoch 12/50
# 25/25 [==============================] - 3s 109ms/step - loss: 0.9822 - accuracy: 0.5102 - val_loss: 1.0250 - val_accuracy: 0.4721
# Epoch 13/50
# 25/25 [==============================] - 3s 106ms/step - loss: 0.9871 - accuracy: 0.5051 - val_loss: 1.0137 - val_accuracy: 0.4975
# Epoch 14/50
# 25/25 [==============================] - 3s 109ms/step - loss: 0.9464 - accuracy: 0.5140 - val_loss: 1.0119 - val_accuracy: 0.4721
# Epoch 15/50
# 25/25 [==============================] - 3s 110ms/step - loss: 0.9337 - accuracy: 0.5381 - val_loss: 1.0625 - val_accuracy: 0.4264
# Epoch 16/50
# 25/25 [==============================] - 3s 112ms/step - loss: 0.9281 - accuracy: 0.5571 - val_loss: 1.0038 - val_accuracy: 0.4772
# Epoch 17/50
# 25/25 [==============================] - 3s 113ms/step - loss: 0.9235 - accuracy: 0.5381 - val_loss: 1.0137 - val_accuracy: 0.4873
# Epoch 18/50
# 25/25 [==============================] - 3s 112ms/step - loss: 0.9156 - accuracy: 0.5558 - val_loss: 1.0113 - val_accuracy: 0.4822
# Epoch 19/50
# 25/25 [==============================] - 3s 105ms/step - loss: 0.9031 - accuracy: 0.5546 - val_loss: 1.0332 - val_accuracy: 0.4721
# Epoch 20/50
# 25/25 [==============================] - 3s 110ms/step - loss: 0.9084 - accuracy: 0.5495 - val_loss: 1.0025 - val_accuracy: 0.4772
# Epoch 21/50
# 25/25 [==============================] - 3s 113ms/step - loss: 0.9108 - accuracy: 0.5596 - val_loss: 1.0014 - val_accuracy: 0.4721
# Epoch 22/50
# 25/25 [==============================] - 3s 110ms/step - loss: 0.9009 - accuracy: 0.5558 - val_loss: 1.0308 - val_accuracy: 0.4924
# Epoch 23/50
# 25/25 [==============================] - 3s 112ms/step - loss: 0.9002 - accuracy: 0.5533 - val_loss: 1.0139 - val_accuracy: 0.4873
# Epoch 24/50
# 25/25 [==============================] - 3s 114ms/step - loss: 0.8989 - accuracy: 0.5584 - val_loss: 1.0378 - val_accuracy: 0.4619
# Epoch 25/50
# 25/25 [==============================] - 3s 114ms/step - loss: 0.9116 - accuracy: 0.5482 - val_loss: 1.0142 - val_accuracy: 0.4873
# Epoch 26/50
# 25/25 [==============================] - 3s 115ms/step - loss: 0.8976 - accuracy: 0.5685 - val_loss: 1.0262 - val_accuracy: 0.4822
# Epoch 27/50
# 25/25 [==============================] - 3s 112ms/step - loss: 0.8959 - accuracy: 0.5495 - val_loss: 1.0316 - val_accuracy: 0.4518
# Epoch 28/50
# 25/25 [==============================] - 3s 109ms/step - loss: 0.8896 - accuracy: 0.5736 - val_loss: 1.0319 - val_accuracy: 0.4721
# Epoch 29/50
# 25/25 [==============================] - 3s 113ms/step - loss: 0.8937 - accuracy: 0.5495 - val_loss: 1.0447 - val_accuracy: 0.4822
# Epoch 30/50
# 25/25 [==============================] - 3s 113ms/step - loss: 0.8781 - accuracy: 0.5761 - val_loss: 1.0108 - val_accuracy: 0.5025
# Epoch 31/50
# 25/25 [==============================] - 3s 107ms/step - loss: 0.8925 - accuracy: 0.5546 - val_loss: 1.0154 - val_accuracy: 0.4569
# Epoch 32/50
# 25/25 [==============================] - 3s 113ms/step - loss: 0.8821 - accuracy: 0.5622 - val_loss: 1.0429 - val_accuracy: 0.4822
# Epoch 33/50
# 25/25 [==============================] - 3s 117ms/step - loss: 0.8918 - accuracy: 0.5787 - val_loss: 1.0163 - val_accuracy: 0.4721
# Epoch 34/50
# 25/25 [==============================] - 3s 114ms/step - loss: 0.8712 - accuracy: 0.5799 - val_loss: 1.0269 - val_accuracy: 0.5076
# Epoch 35/50
# 25/25 [==============================] - 4s 135ms/step - loss: 0.8871 - accuracy: 0.5761 - val_loss: 1.0151 - val_accuracy: 0.4670
# Epoch 36/50
# 25/25 [==============================] - 3s 114ms/step - loss: 0.8622 - accuracy: 0.5812 - val_loss: 1.0565 - val_accuracy: 0.4873
# Epoch 37/50
# 25/25 [==============================] - 3s 114ms/step - loss: 0.8713 - accuracy: 0.5964 - val_loss: 1.0394 - val_accuracy: 0.4822
# Epoch 38/50
# 25/25 [==============================] - 3s 111ms/step - loss: 0.8553 - accuracy: 0.5952 - val_loss: 1.0439 - val_accuracy: 0.4873
# Epoch 39/50
# 25/25 [==============================] - 3s 110ms/step - loss: 0.8881 - accuracy: 0.5749 - val_loss: 1.0388 - val_accuracy: 0.4670
# Epoch 40/50
# 25/25 [==============================] - 3s 109ms/step - loss: 0.8596 - accuracy: 0.5977 - val_loss: 1.0258 - val_accuracy: 0.4670
# Epoch 41/50
# 25/25 [==============================] - 3s 109ms/step - loss: 0.8585 - accuracy: 0.5888 - val_loss: 1.0379 - val_accuracy: 0.4619
# Epoch 42/50
# 25/25 [==============================] - 3s 110ms/step - loss: 0.8824 - accuracy: 0.5812 - val_loss: 1.0677 - val_accuracy: 0.4721
# Epoch 43/50
# 25/25 [==============================] - 3s 110ms/step - loss: 0.8639 - accuracy: 0.6028 - val_loss: 1.0736 - val_accuracy: 0.4162
# Epoch 44/50
# 25/25 [==============================] - 3s 110ms/step - loss: 0.8467 - accuracy: 0.6015 - val_loss: 1.0221 - val_accuracy: 0.4924
# Epoch 45/50
# 25/25 [==============================] - 3s 108ms/step - loss: 0.8312 - accuracy: 0.6079 - val_loss: 1.0616 - val_accuracy: 0.4670
# Epoch 46/50
# 25/25 [==============================] - 3s 107ms/step - loss: 0.8266 - accuracy: 0.6282 - val_loss: 1.0389 - val_accuracy: 0.4772
# Epoch 47/50
# 25/25 [==============================] - 3s 107ms/step - loss: 0.8272 - accuracy: 0.6142 - val_loss: 0.9958 - val_accuracy: 0.5178
# Epoch 48/50
# 25/25 [==============================] - 3s 116ms/step - loss: 0.8265 - accuracy: 0.6129 - val_loss: 1.0590 - val_accuracy: 0.4416
# Epoch 49/50
# 25/25 [==============================] - 3s 111ms/step - loss: 0.8406 - accuracy: 0.6129 - val_loss: 1.0472 - val_accuracy: 0.5025
# Epoch 50/50
# 25/25 [==============================] - 3s 111ms/step - loss: 0.8212 - accuracy: 0.6168 - val_loss: 1.0319 - val_accuracy: 0.4975

# %%
img = keras.preprocessing.image.load_img(
    "hair_types/Curly_Hair/02dac897d1dec9ba8c057a11d041ada8--layered-natural-hair-natural-black-hairstyles.jpg", target_size=image_size
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

predictions = model.predict(img_array)
print(
    "This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions[0])
)
# Out:
# 1/1 [==============================] - 0s 55ms/step
# This image is 0.90 percent curly hair, 0.08 percent straight hair, and 0.02 percent wavy hair.
